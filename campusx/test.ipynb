# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_ollama import ChatOllama

# %%
# model = ChatOllama(model="qwen2.5-coder:7b")    
model = ChatOllama(model="llama3.2:3b")

# %%
answer = model.invoke("hola madrid is which language?")
print(answer)
# Out:
# content='Hola Madrid! "Madrid" can refer to the capital city of Spain, but in this context, it seems you\'re asking about the language.\n\nThe phrase "hola Madrid" could be interpreted as a mix of Spanish and English. In Spanish, "hola" means "hello", while "Madrid" is the name of the city.\n\nSo, if I had to break it down:\n\n* "Hola" is Spanish (Spanish for "hello")\n* "Madrid" is also Spanish (the name of the capital city)\n\nHowever, if you\'re referring to a specific language spoken in Madrid, the answer would be Spanish (Castilian).' additional_kwargs={} response_metadata={'model': 'llama3.2:3b', 'created_at': '2026-04-06T19:18:26.081829Z', 'done': True, 'done_reason': 'stop', 'total_duration': 26279189669, 'load_duration': 334985566, 'prompt_eval_count': 32, 'prompt_eval_duration': 175587295, 'eval_count': 133, 'eval_duration': 25492054428, 'logprobs': None, 'model_name': 'llama3.2:3b', 'model_provider': 'ollama'} id='lc_run--019d643a-f95c-7dc3-a942-33b187f04c77-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 32, 'output_tokens': 133, 'total_tokens': 165}
