# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyPDFLoader

# %%
file_path = '/Users/kara/Desktop/langgraphfcc/RAG/poem.pdf'

loader = PyPDFLoader(file_path)
docs = loader.load()

# %%
text = """I don’t stick to just reading the summary either. While reading I pull out insights I found interesting, and then. I also ask Claude questions about the podcast to clarify relevant points. I find this interactive consumption / wrestling with the summary is better than just putting on headphones and listening while I’m on the go. This “lean-forward” style of consumption is what AI has enabled, and thus far, I feel it seems to lead to better absorption.

The final step is taking the insights I have extracted, and writing it out. I use a combination of dictating out my observations via Wispr Flow, and hand typing to create my highlights / learnings from the podcast that I can share ahead as well. Think of it as an AI Highlight or AILights as I call it. The process of grappling with it, going back and forth with the AI, and turning it into something I can share seems to make for better learning than just listening to the podcast or reading the transcript on Remarkable (my previous podcast consumption route).

To sum up, I don’t think AI has not necessarily increased the number of podcasts that I am able to consume, but it is helping me absorb these better. Still, I don’t think this is a settled position, so I’ll come back with further thoughts over the coming months on this topic.

My notes and thoughts (below) covering the podcasts and articles I consumed over the past month will reflect the above workflow. Let me know what you think of it."""

# %%
splitter = RecursiveCharacterTextSplitter(
    chunk_size = 100,
    chunk_overlap = 10
)

# %%
chunks = splitter.split_text(text)

# %%
len(chunks)
# Out:
# 18

# %%
chunks
# Out:
# ['I don’t stick to just reading the summary either. While reading I pull out insights I found',
#  'I found interesting, and then. I also ask Claude questions about the podcast to clarify relevant',
#  'relevant points. I find this interactive consumption / wrestling with the summary is better than',
#  'than just putting on headphones and listening while I’m on the go. This “lean-forward” style of',
#  'style of consumption is what AI has enabled, and thus far, I feel it seems to lead to better',
#  'to better absorption.',
#  'The final step is taking the insights I have extracted, and writing it out. I use a combination of',
#  'of dictating out my observations via Wispr Flow, and hand typing to create my highlights /',
#  '/ learnings from the podcast that I can share ahead as well. Think of it as an AI Highlight or',
#  'or AILights as I call it. The process of grappling with it, going back and forth with the AI, and',
# ...
