# %%
from langchain_community.document_loaders import CSVLoader

# %%
loader = CSVLoader(file_path='/Users/kara/Desktop/langgraphfcc/RAG/dim_store.csv')

# %%
data = loader.load()

# %%
data[0].page_content
# Out:
# 'store_sk: 1\nstore_code: MEG-NY-001\nstore_name: MegaMart Manhattan\ncity: New York\nstate_province: NY\nregion: Northeast\ncountry: USA\nopen_date: 2018-04-12\nsq_ft: 12000'

# %%
len(data)
# Out:
# 5
