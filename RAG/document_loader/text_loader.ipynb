# %%
from langchain_community.document_loaders import TextLoader
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model="llama-3.1-8b-instant")

# %%
file_path = '/Users/kara/Desktop/langgraphfcc/RAG/poem.txt'
loader = TextLoader(file_path, encoding='utf-8')

# %%
prompt = PromptTemplate(
    template = 'Write a summary for the following poen - \n {poem}',
    input_variable = ['poem']
)

# %%
parser = StrOutputParser()

# %%
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': '/Users/kara/Desktop/langgraphfcc/RAG/poem.txt'}, page_content='A quiet window holds the dawn,\nhalf-light stitched to a waking sky.\nDust floats like forgotten thoughts\nin a room that never asks why.\nThe kettle hums a patient tune,\ntime loosens its careful grip.\nA sparrow writes across the air—\na fleeting, weightless script.\nYou reach for something unnamed,\nit slips between breath and bone;\nnot lost, not found—just passing through,\nlike a place you’ve always known.\nAnd in that pause, the world leans close,\nsoft as a secret kept—\neverything loud falls gently still,\nand even silence feels… depth.')]

# %%
type(docs)
# Out:
# list

# %%
docs[0].metadata
docs[0].page_content
# Out:
# 'A quiet window holds the dawn,\nhalf-light stitched to a waking sky.\nDust floats like forgotten thoughts\nin a room that never asks why.\nThe kettle hums a patient tune,\ntime loosens its careful grip.\nA sparrow writes across the air—\na fleeting, weightless script.\nYou reach for something unnamed,\nit slips between breath and bone;\nnot lost, not found—just passing through,\nlike a place you’ve always known.\nAnd in that pause, the world leans close,\nsoft as a secret kept—\neverything loud falls gently still,\nand even silence feels… depth.'

# %%
type(docs[0])
# Out:
# langchain_core.documents.base.Document

# %%
chain = prompt | model | parser
chain.invoke({'poem': docs[0].page_content})
# Out:
# 'The poem is a serene and contemplative reflection on the moments just before dawn, when the world is quiet and still. It explores the themes of introspection, impermanence, and the fleeting nature of thoughts and experiences. The speaker describes a peaceful scene where time seems to slow down, and even silence takes on a sense of depth and significance. The poem touches on the idea that some things, like our deepest thoughts and feelings, are difficult to grasp or put into words, but can be felt and experienced in the quiet moments of life.'
