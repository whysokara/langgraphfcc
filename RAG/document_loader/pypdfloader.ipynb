# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model="llama-3.1-8b-instant")

# %%
file_path = '/Users/kara/Desktop/langgraphfcc/RAG/poem.pdf'
loader = PyPDFLoader(file_path)

# %%
docs = loader.load()

# %%
type(docs)
# Out:
# list

# %%
len(docs)
# Out:
# 20

# %%
print(docs[0].page_content)
# Out:
# 28
# SHORT P OEMS an d
# PROSE P OEMS
# by
# PIERRE    REVERDY
# translated    by
# MARY A NN C AWS
# brief po ems  and pr ose  poem  pieces
# available  together  or i ndependently i n  script  form
# for us e  for f estival
# by an yone w ho w ants  to pi ck an y  of t hem  up
# 1

# %%
print(docs[0].metadata.keys())
# Out:
# dict_keys(['producer', 'creator', 'creationdate', 'source', 'total_pages', 'page', 'page_label'])

# %%
print(docs[0].metadata)
# Out:
# {'producer': 'OpenOffice.org 1.1.3', 'creator': 'Writer', 'creationdate': '2008-06-18T15:17:15-07:00', 'source': '/Users/kara/Desktop/langgraphfcc/RAG/poem.pdf', 'total_pages': 20, 'page': 0, 'page_label': '1'}
